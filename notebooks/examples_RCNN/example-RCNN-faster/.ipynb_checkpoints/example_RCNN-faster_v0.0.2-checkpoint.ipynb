# %% [markdown]
# # Overview

# %% [markdown]
# __References:__
#
# [Faster R-CNN (object detection) implemented by Keras for custom data from Google’s Open Images Dataset V4](https://towardsdatascience.com/faster-r-cnn-object-detection-implemented-by-keras-for-custom-data-from-googles-open-images-125f62b9141a)
#
# https://github.com/RockyXu66/Faster_RCNN_for_Open_Images_Dataset_Keras
#
# https://github.com/kbardool/keras-frcnn

# %% [markdown]
# # Install Libs

# %%
#!pip install -q --upgrade pyDSlib
# !pip install -q --upgrade tensorflow-datasets
# !pip install -q wget

# %% [markdown]
# # Import Libs

# %%
import tensorflow as tf
import sys, os, warnings, importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wget
import skimage
import cv2
import joblib
import shutil
import gc
import tensorflow_datasets as tfds

# %%
sys.path.insert(0, '/mr3_boltprod_john_t_leonard/ObjDetection/pyDSlib/')

# %%
import pyDSlib as DS
import pyDSlib.ML.NeuralNet as NN
import pyDSlib.ML.NeuralNet.RCNN as RCNN

DS.__version__
# Out:
# pycocotools is not installed. To use pretrained mask-RCNN on coco, run $pip install pycocotools
# '0.3.5'

# %% [markdown]
# # Define Paths

# %%
root_dir = os.path.abspath('../../../../')
data_dir = os.path.join(root_dir, 'ObjDetection_Data')
outputs_dir = os.path.join(root_dir,'outputs')

for dir_ in [data_dir, outputs_dir]:
    if not os.path.isdir(dir_):
        os.makedirs(dir_)
        
print('root_dir:',root_dir)
print('data_dir:', data_dir)
print('outputs_dir', outputs_dir)
# Out:
# root_dir: /mr3_boltprod_john_t_leonard/ObjDetection
# data_dir: /mr3_boltprod_john_t_leonard/ObjDetection/ObjDetection_Data
# outputs_dir /mr3_boltprod_john_t_leonard/ObjDetection/outputs

# %% [markdown]
# # Fetch Dataset

# %% [markdown]
# We'll use coco via tensorflow datasets
#
# __References:__
#
# https://www.tensorflow.org/datasets/catalog/coco

# %%
#Disable progress bar to avoid requiring widget
tfds.disable_progress_bar()

#Instantiate the builder
dsID = 'coco/2017'
builder = tfds.builder(dsID)
# Out:
# INFO:absl:Overwrite dataset info from restored data version.

# %%
builder.info.splits
# Out:
# {'test': <tfds.core.SplitInfo num_examples=40670>,
#  'train': <tfds.core.SplitInfo num_examples=118287>,
#  'validation': <tfds.core.SplitInfo num_examples=5000>}

# %%
print('data_dir', builder.data_dir)
builder.info
# Out:
# data_dir /root/tensorflow_datasets/coco/2017/1.1.0
# tfds.core.DatasetInfo(
#     name='coco',
#     version=1.1.0,
#     description='COCO is a large-scale object detection, segmentation, and
# captioning dataset. This version contains images, bounding boxes "
# and labels for the 2017 version.
# Note:
#  * Some images from the train and validation sets don't have annotations.
#  * Coco 2014 and 2017 uses the same images, but different train/val/test splits
#  * The test split don't have any annotations (only images).
#  * Coco defines 91 classes but the data only uses 80 classes.
#  * Panotptic annotations defines defines 200 classes but only uses 133.
# ',
#     homepage='http://cocodataset.org/#home',
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'image/id': Tensor(shape=(), dtype=tf.int64),
#         'objects': Sequence({
# ...

# %%
warnings.filterwarnings('ignore')
builder.download_and_prepare()
warnings.filterwarnings('default')
# Out:
# INFO:absl:Reusing dataset coco (/root/tensorflow_datasets/coco/2017/1.1.0)

# %%
# fetch text label IDs
labels = list(pd.read_csv(os.path.join(builder.data_dir,'objects-label.labels.txt'), header=None).iloc[:,0])
print('n labels:', len(labels))
labels
# Out:
# n labels: 80
# ['person',
#  'bicycle',
#  'car',
#  'motorcycle',
#  'airplane',
#  'bus',
#  'train',
#  'truck',
#  'boat',
#  'traffic light',
#  'fire hydrant',
#  'stop sign',
#  'parking meter',
#  'bench',
#  'bird',
#  'cat',
#  'dog',
#  'horse',
#  'sheep',
#  'cow',
#  'elephant',
#  'bear',
#  'zebra',
#  'giraffe',
#  'backpack',
#  'umbrella',
#  'handbag',
#  'tie',
#  'suitcase',
#  'frisbee',
#  'skis',
#  'snowboard',
#  'sports ball',
#  'kite',
#  'baseball bat',
#  'baseball glove',
#  'skateboard',
#  'surfboard',
#  'tennis racket',
#  'bottle',
#  'wine glass',
#  'cup',
#  'fork',
#  'knife',
#  'spoon',
#  'bowl',
#  'banana',
#  'apple',
#  'sandwich',
#  'orange',
#  'broccoli',
#  'carrot',
#  'hot dog',
#  'pizza',
#  'donut',
#  'cake',
#  'chair',
#  'couch',
#  'potted plant',
#  'bed',
#  'dining table',
#  'toilet',
#  'tv',
#  'laptop',
#  'mouse',
#  'remote',
#  'keyboard',
#  'cell phone',
#  'microwave',
#  'oven',
#  'toaster',
#  'sink',
# ...

# %% [markdown]
# # Prepare the Data

# %%
#Define some constants
batch_size = 32
n_classes = len(labels)
print('n_classes',n_classes)
# Out:
# n_classes 80

# %%
#Prepare the data generator
# ds = builder.as_dataset(batch_size=batch_size)
# ds_train_gen = tfds.as_numpy(ds['train'])
# ds_test_gen = tfds.as_numpy(ds['test'])

#slice out a subset of the data for development
slice_ = '[:10%]'

#Don't apply a batch size with tfds. It will make all images in a batch the same size and not adjust the bounding box coordinates accordingly
ds_train = tfds.load(dsID, split='train'+slice_)

ds_test = tfds.load(dsID, split='validation'+slice_)

n_training_examples = len(list(ds_train))
n_testing_examples = len(list(ds_test))

print('n_training_examples:', n_training_examples)
print('n_testing_examples:', n_testing_examples)
# Out:
# INFO:absl:Overwrite dataset info from restored data version.
# INFO:absl:Reusing dataset coco (/root/tensorflow_datasets/coco/2017/1.1.0)
# INFO:absl:Constructing tf.data.Dataset for split train[:10%], from /root/tensorflow_datasets/coco/2017/1.1.0
# INFO:absl:Overwrite dataset info from restored data version.
# INFO:absl:Reusing dataset coco (/root/tensorflow_datasets/coco/2017/1.1.0)
# INFO:absl:Constructing tf.data.Dataset for split validation[:10%], from /root/tensorflow_datasets/coco/2017/1.1.0
# n_training_examples: 11829
# n_testing_examples: 500

# %% [markdown]
# # Map the Augmentation Function

# %%
augment_args = {'dtype': tf.float32,
                'flip_left_right':True, 
                'flip_up_down':True, 
                'rot90':True, 
                'smallest_side_length':300, 
                'verbose':0 }

ds_train = ds_train.map(lambda ds_slice: NN.RCNN.augment(split = 'train', ds_slice = ds_slice,
                                                          **augment_args))
ds_train_gen = tfds.as_numpy(ds_train)

ds_test = ds_test.map(lambda ds_slice: NN.RCNN.augment(split='test', ds_slice = ds_slice,
                                                        **augment_args))
ds_test_gen = tfds.as_numpy(ds_test)

# %% [markdown]
# # Visualize The Data

# %%
for i in range(3):
    ds_slice = next(ds_train_gen)
    
    NN.RCNN.plot.img_and_bboxes(ds_slice, labels=labels)
    
    ds_slice = next(ds_test_gen)
    NN.RCNN.plot.img_and_bboxes(ds_slice, labels=labels)
pass
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Instantiate the Model

# %%
model_args = {"backboneID":'ResNet50_pretrained', 
              'RPN_Conv2D_input_filters':512, 
              'RPN_Conv2D_input_kernel_size':(3, 3), 
              'n_anchors':9, 
              'n_classes': len(labels), 
              'RPN_optimizer': tf.keras.optimizers.Adam(learning_rate = 1e-5), 
              'ROI_optimizer': tf.keras.optimizers.Adam(learning_rate = 1e-5), 
              'path_model_dir': None}

model = NN.RCNN.faster.model(**model_args)

# %% [markdown]
# # Add the RPN Ground Truth to the dataset

# %%
importlib.reload(NN)
importlib.reload(NN.blocks)
importlib.reload(NN.losses)
importlib.reload(NN.ResNet50)
importlib.reload(NN.RCNN._RPN_anchors)
importlib.reload(NN.RCNN._augment)
importlib.reload(NN.RCNN)
importlib.reload(NN.RCNN._RPN_anchors)
importlib.reload(NN.RCNN._augment)
importlib.reload(NN.RCNN)
importlib.reload(NN.RCNN.plot)
importlib.reload(NN.RCNN.faster)

foo = ds_train.map(lambda ds_slice: NN.RCNN.RPN_anchors(ds_slice,
                                                         RPN_stride = 16,
                                                         anchor_box_sizes = (64, 128, 256),
                                                         model_backbone = model.model_backbone
                                                         ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-24dc2774d67b> in <module>
#      12 importlib.reload(NN.RCNN.faster)
#      13
# ---> 14 foo = ds_train.map(lambda ds_slice: NN.RCNN.RPN_anchors(ds_slice,
#      15                                                          RPN_stride = 16,
#      16                                                          anchor_box_sizes = (64, 128, 256),
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls)
#    1586     """
#    1587     if num_parallel_calls is None:
# -> 1588       return MapDataset(self, map_func, preserve_cardinality=True)
#    1589     else:
#    1590       return ParallelMapDataset(
#
# ...

# %%
importlib.reload(NN)
importlib.reload(NN.blocks)
importlib.reload(NN.losses)
importlib.reload(NN.ResNet50)
importlib.reload(NN.RCNN._RPN_anchors)
importlib.reload(NN.RCNN._augment)
importlib.reload(NN.RCNN)
importlib.reload(NN.RCNN._RPN_anchors)
importlib.reload(NN.RCNN._augment)
importlib.reload(NN.RCNN)
importlib.reload(NN.RCNN.plot)
importlib.reload(NN.RCNN.faster)


# graph = NN.RCNN.faster._graph(img_shape = (300, 600,3),n_classes=n_classes)
# display(graph)

model_all, model_RPN, model_ROI, model_backbone = NN.RCNN.faster._models(n_classes=n_classes,
                                                                         backboneID='ResNet50_pretrained')
# display(model_all.summary())
# del model_all
# del model_RPN
# del model_ROI

NN.RCNN.RPN_anchors(ds_slice, model_backbone= model_backbone)

# model = NN.RCNN.faster.model(n_classes=n_classes)
# model.
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/data_structures.py:720: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if not isinstance(wrapped_dict, collections.Mapping):
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py:544: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(inputs, collections.Sequence):

# %%
for bbox_idx, bbox in enumerate(ds_slice['objects']['bbox']):
    print(bbox_idx, bbox)
# Out:
# 0 [0.44197604 0.53508    0.752006   0.80196   ]
# 1 [0.41446108 0.59404    0.71398205 0.84486   ]

# %%
_np.array([ds_slice['image']]).shape
# Out:
# (1, 334, 500, 3)

# %%
model_backbone.predict(_np.array([ds_slice['image']])).shape
# Out:
# (1, 11, 16, 2048)

# %%
tf.

# %%
l1 = tf.keras.layers.Conv2D(filters=2, kernel_size=2)
l1

# %%
l1.name
# Out:
# 'conv2d_5'
